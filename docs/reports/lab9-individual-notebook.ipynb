# %% [markdown]
# # Individual Lab Notebook

# %% [markdown]
# ## 3/24/26 Entry
#
# ### Objectives
# - Containerize the user API
# - Deploy to Azure Container Apps
# - Create separate deployment assets and documentation for the app and API
#
# ### Review
# The user API was containerized and deployed to Azure Container Apps. A `Dockerfile`, `docker-compose.yml`, and `containerapp.yaml` were created for the API. The API connects to MongoDB so no local database service is needed. The app and API were separated into two independent deployments with their own assets and documentation — API under `/deploy/api/` and `/docs/deploy/api/`, and the app under `/deploy/app/` and `/docs/deploy/app/`. Both services were pushed to Docker Hub and deployed to Azure Container Apps.
#
# - Dockerfile, docker-compose.yml, and containerapp.yaml created for the user API
# - MongoDB Atlas connection (no local DB service required)
# - Separate deployment assets for app (`/deploy/app/`) and API (`/deploy/api/`)
# - Separate deployment documentation for app (`/docs/deploy/app/`) and API (`/docs/deploy/api/`)
# - Both images published to Docker Hub
# - Both services deployed to Azure Container Apps
#
# ### Retro
# - AI was used for the initial deployment prompt.
# - Linked here: [Initial Prompt file: 09_prompts.md](../prompts/09_prompts.md)
# - The generated output was reviewed and adapted to fit the project (FastAPI + NiceGUI, MongoDB Atlas, Azure Container Apps).

# %% [markdown]
# ## 3/26/26 Entry
#
# ### Objectives
# - Do the lab report.
#
# ### Review
# All implementation work for the week was completed. The remaining task was the lab report, which is now completed with help from the group.
#
# ### Retro
# No AI was used for the content of the lab report, only for structuring.

# %% [markdown]
# ## Understanding
# My understanding this week feels solid. Containerization with Docker makes sense to me after spending time actully doing it and tracing the process.
